// %% [markdown]
// # Exercice et résumé du cours en Javascript

// %% [markdown]
// !!! warning Affichage
//
// Sur un notebook javascript, il n'y a pas de page web, l'affichage ne se fait que sur la console avec la fonction `console.log`.
//
// On ne peut pas utiliser `alert` ou `document.write`
//
// !!!
//
// Exemple:

// %%
console.log("hello world:")

// %% [markdown]
// !!! warning probleme de blocage
//
// Si jamais vous votre code que vous pensez correcte ne renvoie pas de résultat. Il est possible que le code tourne à vide ou fait une boucle infinie
//
// Pour le déblocage
// + Enregistrer votre travail en local en cliquant sur l'icône d'enregistrement.
// ![image_e4777a27](attachment:image_e4777a27)
//
// + Rafraichir la page web
// + Faire **Fichier** puis **Ouvrir** et recharger le fichier **Untitled.ipynb**
// !!!

// %% [markdown]
// # Résumé du cours
//
// + Mot clé `var`
//     On utilise les mots clés :  `var` , `const` et `let` pour déclarer une variable, et on utilise `=` pour affecter une valeur à la variable.
//
// + Variables typées dynamiquement
//
//     Les variables sont typées dynamiquement, ce qui veut dire que l'on n'a pas besoin de spécifier le type de contenu que la variable va contenir.
//
// + Opérations
//     Grâce à différents opérateurs, on peut faire des opérations entre les variables.
//     Voici le liste des principaux opérateurs avec les compattibilités des navigateurs : <a target="_blanck" href="https://developer.mozilla.org/fr/docs/Web/JavaScript/Reference/Objets_globaux/Math">les opérateurs Javascript</a>.
//
// + Concaténation avec l'opérateur `+`.
// + Intéraction avec `prompt()`
//
// Tout ce qui est écrit dans le champ de texte de `prompt()` est récupéré sous forme d'une chaîne de caractères.
// + Conversion d'une chaine de caractére en entier avec `parseInt()`, et en flottant avec `parseFloat()`.

// %% [markdown]
// ## Un exemple

// %%
var a, b, produit,somme;
a = prompt('Donnez un nombre');
b= prompt('Donnez un autre nombre :');
a=parseFloat(a) ; // On convertit la chaîne de caractère a en flottant
b=parseFloat(b); // On convertit la chaîne de caractère b en flottant
produit = a*b;
somme=a+b;
console.log('Le produit est '+ produit+', et la somme est '+ somme);

// %% [markdown]
// # Exercice 2
//
// Ecrire un script Javascript qui pour un triangle ABC rectangle en A, demande la longueur AB, la longueur AC et affiche une valeur approchée de l'hypoténuse BC.
//
// Sur <a target= "_blank" href="https://capytale2.ac-paris.fr/web/c/c55b-2601207">CAPYTALE</a>, vous nommerez votre fichier : **Exercice2.html** et devez faire figurer le lien vers ce fichier sur votre page web .
//
// !!! warning Html et javascipt
//
// Sur la page Html, n'oubliez pas les balises **&lt;script>&lt;/script>** et remplacer `console.log` par `alert` ou `document.write`.
// !!!

// %%
//Tests

// %% [markdown]
// # Les conditions
//
// ```javascript
// if ( /* condition */ )
// {
//     // Du code…
// } else {
//     // Du code…
// }
// ```
//
//
// + Les opérateurs logiques en javaScript
//
//     + test d'égalité `==` , supérieur à : `>` , supérieur ou égal à : `>=`,  et  différent de `!=`
//
//     + contenu et type égal à : `===`  , et contenu et type différent de : `!==`
//     + le ET logique se traduit par `&&`.
//     + le OU logique par : `||`
//     + la négation par le point d'exclamation : `!` .
//
//
// + La condition `else if` permet de combiner les conditions.

// %% [markdown]
// # Exercice 3
//
// Ecrire un script Javascript qui pour un triangle ABC, demande la longueur AB, la longueur AC et la longueur BC et affiche si ce triangle est rectangle (et en quel sommet) ou si il ne l'est pas.
//
// Sur <a target= "_blank" href="https://capytale2.ac-paris.fr/web/c/c55b-2601207">CAPYTALE</a>, vous nommerez votre fichier : **Exercice3.html** et devez faire figure le lien vers ce fichier sur votre page web.
// Vous devrez tester votre script avec :
//
//   + ABC tel que AB = 3, AC = 4 et BC = 5 qui drevrait afficher : "ABC est rectangle en A" ;
//   + ABC tel que AB = 50, AC = 30 et BC = 40 qui drevrait afficher : "ABC est rectangle en C" ;
//   + ABC tel que AB = 6, AC = 10 et BC = 8 qui drevrait afficher : "ABC est rectangle en B" ;
//   + ABC tel que AB = 3, AC = 4 et BC = 6 qui drevrait afficher : "ABC n'est pas rectangle".
//
// !!! warning Html et javascipt
//
// Sur la page Html, n'oubliez pas les balises **&lt;script>&lt;/script>** et remplacer `console.log` par `alert` ou `document.write`.
// !!!

// %%
//Tests

// %% [markdown]
// # Les structures itératives

// %% [markdown]
// ## La boucle `for`
//
// La boucle `for` est une boucle utilisée pour répéter une liste d'instructions un certain nombre de fois.
//
// ### Exemple

// %%
var somme=0;

for (var N=1 ; N<=5 ; N=N+1 ) // syntaxe (var compteur=valeur départ ; compteur<= valeur fin ; incrément)
{
    somme=somme+N;
}

console.log('somme= ' + somme + ' et N=' + N ); // Affiche « somme = 15 et N = 6 » , la dernière valeur de N est 6 ce qui invalide la condition

// %% [markdown]
// # Exercice 4
// Ecrire  un script Javascript qui fait la somme des nombres inférieurs à 100 qui sont  des multiples de 7.
//
// Sur <a target= "_blank" href="https://capytale2.ac-paris.fr/web/c/c55b-2601207">CAPYTALE</a>, vous nommerez votre fichier : **Exercice4.html** et devez faire figure le lien vers ce fichier sur votre page web : exercices JavaScript.
// !!! warning Html et javascipt
//
// Sur la page Html, n'oubliez pas les balises **&lt;script>&lt;/script>** et remplacer `console.log` par `alert` ou `document.write`.
// !!!

// %% [markdown]
// ## La boucle `while`
// La boucle  `while` permet de répéter une liste d'instructions tant que la condition est vérifiée.
//
// ### Exemple

// %%
var N = 0,somme=0;

while (N < 5) 
{
    N=N+1; // ou N++
    somme=somme+N;
}

console.log('somme= ' + somme + ' et N=' + N ); // Affiche « somme = 15 et N = 5 »

// %% [markdown]
// # Exercice 5
// Ecrire un script Javascript qui tente de faire deviner un entier entre 1 et 100 de votre choix et affiche, plus petit, ou plus grand jusqu'à la victoire.
//
// Voir la <a href="https://youtu.be/pMMvuSCB7WA">vidéo</a>
//
// Commencer par fixer votre nombre à deviner puis essayer de le générer aléatoirement dans un deuxième temps.
//
// Sur <a target= "_blank" href="https://capytale2.ac-paris.fr/web/c/c55b-2601207">CAPYTALE</a>, vous nommerez votre fichier : **Exercice5.html** et devez faire figure le lien vers ce fichier sur votre page web : exercices JavaScript.
// !!! warning Html et javascipt
//
// Sur la page Html, n'oubliez pas les balises **&lt;script>&lt;/script>** et remplacer `console.log` par `alert` ou `document.write`.
// !!!
//
// !!! warning Boucle infinie
//
// Vous serez ammenés à utiliser une boucle `while` . Je vous invite fortement à rajouter un compteur dans votre boucle pour éviter les boucles infinies. De la maniére suivante:
// !!!

// %%
var anticrash = 0;

// Du code…

while (... && anticrash < 20) 
{
  // Du code…
  ...

 anticrash=anticrash+1;

}

// %%
//Tests

// %% [markdown]
// # Les fonctions
//
// Il est aussi possible d'en créer, avec le mot-clé `function` .
//
// # Exemple:

// %%
function DireBonjour(x)
{
    return ('Bonjour  ' + x); // L'instruction « return » suivie de la concaténation de 'Bonjour' et de la variable chaîne x
}
nom=prompt('Quel est votre prénom svp ?'); // On demande le prénom à l'utilisateur
console.log(DireBonjour(nom));

// %% [markdown]
// # Exercice 6
//
// 1. Ecrire une **fonction** `a_lettre_e(phrase)` Javascript qui teste la présence de la lettre "e" minuscule dans une chaîne de caractères passée en paramètre. Cette fonction doit renvoyer `false` ou `true`. Utilisez votre fonction après avoir demandé une chaîne de caractères via la fonction `prompt()`.
//
// 2. Ecrire une **fonction** `nombre_e(phrase)` Javascript qui compte le nombre de lettre "e" minuscule dans une chaîne de caractères passée en paramètre. Cette fonction doit renvoyer `false` ou `true`. Utilisez votre fonction après avoir demandé une chaîne de caractères via la fonction `prompt()`.
//
// Sur <a target= "_blank" href="https://capytale2.ac-paris.fr/web/c/c55b-2601207">CAPYTALE</a>, vous nommerez votre fichier : **Exercice6.html** et devez faire figure le lien vers ce fichier sur votre page web :
//
// !!! warning Html et javascipt
//
// Sur la page Html, n'oubliez pas les balises **&lt;script>&lt;/script>** et remplacer `console.log` par `alert` ou `document.write`.
// !!!
//
// !!! note Aide
//
// La méthode `.length` renvoie la longueur d'une chaine `C` et la méthode `.charAt(position)` le caractère à la position précisée dans la chaîne `C`.
//
// Voici un exemple d'utilisation : <a target="blank" href="https://prolifaxe.github.io/images/pdf/NSI/premiere/html-premiere/Javascript-Fonctions-Exemple2.html">lien exemple 2</a>.
// !!!

// %%
var C='abcdefg'; // C est une chaine de caracteres
long=C.length;   // long est la longueur de la chaine, ici 7 
lettre=C.charAt(0); // lettre est le caractere de la chaine en position 0 (le 1er caractere)
console.log('Chaine=' + C + ' , longueur = '+ long + ', premier caractere = ' + lettre );

// %%
//Code

// %%
//Tests

// %% [markdown]
// # <a href="https://prolifaxe.github.io/coursdecourtois/JavaScriptPremiere.html#QCM">Pour continuer Cliquer ici</a>
