// %% [markdown]
// # Exercices supplémentaires  JavaScript

// %% [markdown]
// !!! warning Affichage
//
// Sur un notebook javascript, il n'y a pas de page web, l'affichage ne se fait que sur la console avec la fonction `console.log`.
//
// On ne peut pas utiliser `alert` ou `document.write`
//
// !!!
//
// Exemple:

// %%
console.log("hello world:")
// Out:
// hello world:

// %% [markdown]
// Pendant le devoir vous pourrez
// consulter:
//
// + HTML et CSS, le cours de base : https://prolifaxe.github.io/coursdecourtois/HTMLCSSPremiere.html
// + JavaScript le cours : http://jerome.courtois2.free.fr/JavaScriptPremiere.html
// + JavaScript la documentation : https://devdocs.io/javascript/
// + CSS la documentation : https://devdocs.io/css/

// %% [markdown]
// # Exercices supplémentaires  JavaScript

// %% [markdown]
// # Exercice 1
// Faire une fonction `est_majeur` qui prend l'age d'une personne en paramétre et renvoie `true` si l'utilisateur est majeur sinon `false`
//
// Exemple
// ```javascript
// >>>est_majeur(10)
// false
// >>>est_majeur(35)
// true
// ```

// %% [markdown]
// ## Code à mettre sur <a target ="_blank" href="https://capytale2.ac-paris.fr/web/c/e89d-5817504">Capytale</a>

// %%
function est_majeur(age){

}

// %% [markdown]
// # Tests (ne pas mettre sur Capytale)

// %%
  var car=2;
  console.log("est_majeur("+car+")="+est_majeur(car));
  car=10;
  console.log("est_majeur("+car+")="+est_majeur(car));
    car=18;
  console.log("est_majeur("+car+")="+est_majeur(car));
    car=45;
  console.log("est_majeur("+car+")="+est_majeur(car));
    car=60;
  console.log("est_majeur("+car+")="+est_majeur(car));
// Out:
// est_majeur(2)=undefined
// est_majeur(10)=undefined
// est_majeur(18)=undefined
// est_majeur(45)=undefined
// est_majeur(60)=undefined

// %% [markdown]
// <span style="color:red">ATTENTION, pensez bien à enregister avant de commencer la suite.<span>

// %% [markdown]
// # Exercice 2
// En utilisant la boucle for, faire une fonction `tableMul(N)` qui **affiche** la table de multiplication du chiffre N. Cette fonction ne renvoie rien
//
// Exemple:
// ```javascript
// >>>tableMul(5)
// 0x5=0
// 1x5=5
// 2x5=10
// 3x5=15
// 4x5=20
// 5x5=25
// 6x5=30
// 7x5=35
// 8x5=40
// 9x5=45
// ```

// %% [markdown]
// ## Code à mettre sur <a target ="_blank" href="https://capytale2.ac-paris.fr/web/c/e89d-5817504">Capytale</a>

// %%
function tableMul(N){

  
}

// %% [markdown]
// ## Tests (ne pas mettre sur Capytale)

// %%
 ///Tests

 var N=5;
  
tableMul(N)

// %% [markdown]
// <span style="color:red">ATTENTION, pensez bien à enregister avant de commencer la suite.<span>

// %% [markdown]
// # Exercice 3
// Compléter une fonction `escalier(N)` qui affiche **N** lignes et pour chaque ligne **i** , i fois le nombre i. Cette fonction ne renvoie rien.
//
// On utilisera deux boucles `for`.
//
// Exemple:
// ```javascript
// >>>escalier(5)
// 1
// 22
// 333
// 4444
// 55555
// ```

// %% [markdown]
// ## Code à mettre sur <a target ="_blank" href="https://capytale2.ac-paris.fr/web/c/e89d-5817504">Capytale</a>

// %%
function escalier(N){
    for (...;...;...){
        ligne="";
        for(...;...;...){
            
            ligne=...;
        }
        consosol.log(...);
    }

  
}

// %% [markdown]
// ## Tests (ne pas mettre sur Capytale)

// %%
var N=2;
escalier(N);
N=5;
escalier(N)

// %% [markdown]
// # Exercice 4
// Ecrire une fonction `somme(N)` qui **renvoie** la somme des nombres entiers strictement inférieur à **N** qui sont des multiples de 3 mais qui ne sont pas des multiples de 5
//
//
//
// Exemple:
// ```javascript
// >>>somme(5)
// 3
// >>>somme(15)
// 30
// >>>somme(16)
// 30
// ```

// %% [markdown]
// ## Code à mettre sur <a target ="_blank" href="https://capytale2.ac-paris.fr/web/c/e89d-5817504">Capytale</a>

// %%
function somme(N){
    
}

// %% [markdown]
// ## Tests (ne pas mettre sur Capytale)

// %%
  var car=2;
  console.log("somme("+car+")="+somme(car));
  car=10;
  console.log("somme("+car+")="+somme(car));
    car=15;
  console.log("somme("+car+")="+somme(car));
    car=16;
  console.log("somme("+car+")="+somme(car));
    car=60;
  console.log("somme("+car+")="+somme(car));

// %% [markdown]
// # Exercice 5
// Ecrire une fonction `moyenne` qui **renvoie** la moyenne des termes d’une liste. Arrondir avec deux chiffres apres la virgule
//
// Exemple:
// ```javascript
// >>>moyenne([5,10])
// 7.5
//
// ```

// %% [markdown]
// ## Code à mettre sur <a target ="_blank" href="https://capytale2.ac-paris.fr/web/c/e89d-5817504">Capytale</a>

// %%
function moyenne(a){

}

// %% [markdown]
// ## Tests (ne pas mettre sur Capytale)

// %%
var car=[5,10];
  console.log("moyenne("+car+")="+moyenne(car));
  car=[1,2,3,4,5];
  console.log("moyenne("+car+")="+moyenne(car));
    car=[-1,-2,-10];
  console.log("moyenne("+car+")="+moyenne(car));
    car=[-5,35,10];
  console.log("moyenne("+car+")="+moyenne(car));
    car=[-5,5,5,5];
  console.log("moyenne("+car+")="+moyenne(car));
// Out:
// moyenne(5,10)=undefined
// moyenne(1,2,3,4,5)=undefined
// moyenne(-1,-2,-10)=undefined
// moyenne(-5,35,10)=undefined
// moyenne(-5,5,5,5)=undefined
