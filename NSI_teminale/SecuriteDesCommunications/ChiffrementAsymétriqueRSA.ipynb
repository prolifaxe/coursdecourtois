# %% [markdown]
# # La cryptologie
#
# La cryptologie,étymologiquement est la « science du secret »
#
# Elle englobe :
#    + la cryptographie : c'est la science du chiffrement et du déchiffrement
#    + la cryptanalyse : c'est l'analyse de la cryptographie. On utilise alors le verbe décrypter.
#
# La cryptographie s'intéresse à la protection des données tandis que la cryptanalyse a pour objectif de corrompre les propriétés apportées par la cryptographie. On parle couramment d'attaque sur un cryptosystème.

# %% [markdown]
# # Histoire
# Les nouveautés en matière de cryptologie sont apparues pendant les différents conflits émaillés tout au long de l'histoire. Les cryptosystèmes.
# les plus connus :
# + Le chiffrement de César qui fut utilisé pendant la guerre des Gaules et
# + La machine allemande Enigma utilisée pendant la seconde guerre mondiale et décryptée par l'équipe de Alan Turing.
#
# Dans les deux cas, le chiffrement, c'est-à-dire le brouillage du message échangé, est assuré par une même clef secrète possédée par tous les participants à l'échange d'information. On parle ici de **chiffrement symétrique**. Chaque participant à l'échange du secret possède la même clef de chiffrement.
#
# Le défaut de cette méthode nécessite la communication préalable de la clef de chiffrement.
#
# Comment communiquer cette clef de manière sécurisée ? Il faut attendre les travaux de W. Diffie et M. Hellman , et de R. Merkle dans les années 70 sur le **chiffrement asymétrique**, aussi appelé chiffrement à clef publique pour avoir une réponse satisfaisante.

# %% [markdown]
# # Résumé
# Il y a deux manières principales de chiffrement:
# + Le **chiffrement symétrique** qui utilise une clé unique, connue seulement de l’émetteur et du récepteur. Le chiffrement et le déchiffrement utilise la même clé.
# + Le **chiffrement asymétrique** qui utilise un couple de clé, l’une publique connue de tout le monde, l’autre privée connue uniquement par le récepteur. L’émetteur chiffre le message avec la clé publique. Le récepteur le déchiffre avec la clé privée.

# %% [markdown]
# # Le chiffrement symétrique
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exemples
#
# ### Le chiffrement de Cesar:
#
# On fait un décalage dans l'alphabet. Par exemple avec la clef K=10, "NSI" devient "XCS".
#
#
# ### Exercice 1
# Completez le code suivant et testez. Un caractére de l'alphabet sera toujours mis en majuscule. Un caractere qui n'est pas dans l'alphabet ne sera pas codé.

# %%
ALPHABET='ABCDEFGHIJKLMNOPQRSTUVWXYZ'

def position_alphabet(lettre):
    return ALPHABET.find(lettre)

def cesar(message, decalage):

    resultat = ''
    for ... in message :
        if lettre in ALPHABET :
            indice = ( ... )%26
            resultat = resultat + ALPHABET[indice]
        else:
            resultat = ...
    return resultat
# Out:
#   File "<input>", line 9
# SyntaxError: cannot assign to Ellipsis

# %%
#TESTER VOTRE CODE ICI
exec(bytes('吣卅⁔久䌠䅌剉椊灭牯⁴慲摮浯䄊偌䅈䕂䩔䩅㵅䄧䍂䕄䝆䥈䭊䵌低児卒啔坖奘❚搊晥瀠獯瑩潩彮污桰扡瑥䕊䕊氨瑥牴⥥਺††敲畴湲䄠偌䅈䕂䩔䩅⹅楦摮氨瑥牴⥥搊晥挠獥牡䕊䕊洨獥慳敧‬敤慣慬敧㨩 †爠獥汵慴⁴‽✧ †映牯氠瑥牴⁥湩洠獥慳敧㨠⌠ †††椠⁦敬瑴敲椠⁮䱁䡐䉁呅䕊䕊㨠 †††††椠摮捩⁥‽瀨獯瑩潩彮污桰扡瑥氨瑥牴⥥†搫捥污条⥥㈥‶ਣ††††††敲畳瑬瑡㴠爠獥汵慴⁴‫䱁䡐䉁呅䕊䕊楛摮捩嵥 †††攠獬㩥 †††††爠獥汵慴⁴‽敲畳瑬瑡⬠氠瑥牴⁥ਣ††敲畴湲爠獥汵慴ੴ畮扭牥潟彦瑳楲杮⁳‽〱〰氊湥瑧彨景獟牴湩⁧‽ਸ牥敲牵䘽污敳昊牯砠椠⁮慲杮⡥畮扭牥潟彦瑳楲杮⥳਺†敤慣爽湡潤⹭慲摮湩⡴ㄭ〰ㄬ〰਩†㵡✧樮楯⡮慲摮浯挮潨捩⡥䱁䡐䉁呅䕊䕊∫␦ℿ∪潦⁲ 湩爠湡敧氨湥瑧彨景獟牴湩⥧਩†晩挠獥牡䕊䕊愨搬捥⥡㴡散慳⡲ⱡ敤慣㨩 †瀠楲瑮∨汉礠愠甠敮攠牲略⁲癡捥氠⁥潭≴愬∬瑥氠⁥敤慣慬敧Ⱒ敤慣਩††牥敲牵吽畲੥††牢慥੫晩攠牲略㵲䘽污敳਺††牰湩⡴䈢慲潶瘠瑯敲挠摯⁥敭猠浥汢⁥灯牥瑡潩湮汥∮਩吣卅⁔佄啃䕍呎䥁佔੎浩潰瑲椠੯浩潰瑲猠獹搊晥琠獥䑴捯昨㨩 †猠摴畯彴㴠猠獹献摴畯ੴ††祳⹳瑳潤瑵㴠椠⹯瑓楲杮佉⤨ †琠祲਺††††敨灬昨਩††††ㅳ㴠猠獹献摴畯⹴敧癴污敵⤨ †††猠獹献摴畯⁴‽瑳潤瑵੟††††ㅳ氮睯牥⤨ †††椠⁦漢瑵•潮⁴湩猠㨱 †††††瀠楲瑮∨潖牴⁥潤畣敭瑮瑡潩⁮獥⁴湩潣灭敬整尮≮਩††硥散瑰਺††††祳⹳瑳潤瑵㴠猠摴畯彴 †††栠汥⡰⥦琊獥䑴捯挨獥牡','u16')[2:])

# %%
#TEST EN CLAIR
import random
ALPHABETJEJE='ABCDEFGHIJKLMNOPQRSTUVWXYZ'

def position_alphabetJEJE(lettre):
    return ALPHABETJEJE.find(lettre)

def cesarJEJE(message, decalage):
    resultat = ''
    for lettre in message : #
        if lettre in ALPHABETJEJE :
            indice = (position_alphabet(lettre) + decalage)%26 #
            resultat = resultat + ALPHABETJEJE[indice]
        else:
            resultat = resultat + lettre #
    return resultat
number_of_strings = 1000
length_of_string = 8
erreur=False
for x in range(number_of_strings):
  deca=random.randint(-100,100)
  a=''.join(random.choice(ALPHABETJEJE+"&$?!*") for _ in range(length_of_string))
  if cesarJEJE(a,deca)!=cesar(a,deca):
    print("Il y a une erreur avec le mot",a,"et le decalage",deca)
    erreur=True
    break
if erreur==False:
    print("Bravo votre code me semble operationnel.")
#TEST DOCUMENTAITON
import io
import sys
def testDoc(f):
    stdout_ = sys.stdout
    sys.stdout = io.StringIO()
    try:
        help(f)
        s1 = sys.stdout.getvalue()
        sys.stdout = stdout_
        s1.lower()
        if "out" not in s1:
            print("Votre documentation est incomplete.\n")
    except:
        sys.stdout = stdout_
        help(f)

testDoc(cesar)
# Out:
# Traceback (most recent call last):
#   File "<input>", line 23, in <module>
#   File "<input>", line 12, in cesarJEJE
# NameError: name 'position_alphabet' is not defined

# %% [markdown]
# ### Le chiffrement avec le masque jetable
#
# On a une clef qui est de la même taille que le message et on chiffre avec XOR (`^` en python). Cette clé est choisie à l'avance entre les deux personnes souhaitant communiquer. Elle n'est connue que d'elles.
#
# Par exemple, on choisie "NSI" est le message en clair.
# + On remplace les lettres N.S.I par leur code ASCII N=1001110, S=1010011 et I=1001001
# + On concatene ces valeurs : $NSI=1001110 1010011 1001001_2=1288649_{10}$
# + Pour la clef, on choisit un nombre binaire aléatoire de la taille du message (ici $3\times 7=21$): $K=101110101010001110110_2=1528950_{10}$
#
# On fait le XOR des deux valeurs $K \oplus NSI=001001111110110111111_2=327103_{10}$
#
# Le chiffrement de "NSI" est alors $chiffre=327103_{10}$
#
# Pour le déchiffrement on fait $K\oplus chiffre= 1288649_{10}$
#
# ### Exercice 2
# + Ecrire une fonction python `str_nombre(message)` qui prend une chaine de caractere alphabetique minuscule ou majuscule en argument et qui renvoie le nombre (int) correspondant en concatenant les codes ASCII.
#
# + Ecrire une fonction python `chiffreMasque(message)` qui prend un message en argument, qui choisit une clef aléatoire et renvoie le chiffré et la clef.
# + On donne la fonction python `dechiffreMasque(chiffre,clef)` qui prend en argument un chiffré et une clef de déchiffrement et renvoie le message en clair sous forme d'une chaine de caractere. Il faut la commenter.
#
# ```python
# >>>str_nombre("NSI")
# 1288649
# >>>chiffreMasque("NSI")
# 327103,1528950
# >>>dechiffreMasque(327103,1528950)
# 'NSI'
# ```
#
# ### Exercice 2 bis (Facultatif)
# On peut faire le même exercice pour n'importe quel caractére affichable. C'est plus difficile.
#
#  **indication** :
# + Pour être sûr que la chaine en binaire fasse 7 bits on pourra utiliser la méthode `"chaine binaire".rjust(7,"0")`. Si la chaine a moins de 7 caracteres, cela ajoute des zeros en début de chaine.
# + `from string import printable` fourni la liste des caractéres affichables.

# %%
#CODE
def str_nombre(message):
    pass

# %%
# TESTER VOTRE CODE ICI
exec(bytes('吣卅⁔湥䌠䅌剉椊灭牯⁴慲摮浯椊灭牯⁴瑳楲杮椊灭牯⁴潩椊灭牯⁴祳ੳ敤⁦瑳彲潮扭敲䕊䕊洨獥慳敧㨩 †挠慨湩㵥∢ †映牯椠椠⁮敭獳条㩥 †††挠慨湩㵥档楡敮戫湩漨摲椨⤩㉛崺爮番瑳㜨∬∰਩††敲畴湲椠瑮挨慨湩ⱥ⤲搊晥朠瑥慐獳潷摲䕊䕊氨湥瑧⥨਺††瑳⁲‽瑳楲杮愮捳楩江瑥整獲 †爠瑥牵⁮✧樮楯⡮慲摮浯挮潨捩⡥瑳⥲映牯椠椠⁮爠湡敧氨湥瑧⥨਩牥敲牵䘽污敳昊牯椠椠⁮慲杮⡥〱〰⤰਺††㵭慲摮浯爮湡楤瑮㐨ㄬ⤵ †愠朽瑥慐獳潷摲䕊䕊洨਩††晩琠灹⡥瑳彲潮扭敲愨⤩㴡湩㩴 †††瀠楲瑮∨敌琠灹⁥敤猠牯楴渠攧瑳瀠獡挠牯敲瑣⤢ †††攠牲略㵲牔敵 †††戠敲歡 †攠楬⁦敬⡮楢⡮瑳彲潮扭敲愨⤩㉛崺┩ℷ〽愠摮氠湥戨湩猨牴湟浯牢⡥⥡嬩㨲⥝㜥㴡㨶 †††瀠楲瑮∨慌琠楡汬⁥敤氠⁡档楡敮Ⱒⱡ渢攧瑳瀠獡挠牯敲瑣∮਩††††牥敲牵吽畲੥††††牢慥੫††汥晩猠牴湟浯牢䩥䩅⡅⥡㴡瑳彲潮扭敲愨㨩 †††††††瀠楲瑮∨汉礠愠甠敮攠牲略⁲癡捥氠⁥潭≴愬਩††††††††牥敲牵吽畲੥††††††††牢慥੫晩攠牲略㵲䘽污敳਺††牰湩⡴䈢慲潶瘠瑯敲挠摯⁥敭猠浥汢⁥灯牥瑡潩湮汥∮਩吣卅⁔佄啃䕍呎䥁佔੎敤⁦整瑳潄⡣⥦਺††瑳潤瑵 ‽祳⹳瑳潤瑵 †猠獹献摴畯⁴‽潩匮牴湩䥧⡏਩††牴㩹 †††栠汥⡰⥦ †††猠‱‽祳⹳瑳潤瑵朮瑥慶畬⡥਩††††祳⹳瑳潤瑵㴠猠摴畯彴 †††猠⸱潬敷⡲਩††††晩∠畯≴渠瑯椠⁮ㅳ਺††††††牰湩⡴嘢瑯敲搠捯浵湥慴楴湯攠瑳椠据浯汰瑥⹥湜⤢ †攠捸灥㩴 †††猠獹献摴畯⁴‽瑳潤瑵੟††††敨灬昨਩整瑳潄⡣瑳彲潮扭敲','u16')[2:])

# %%
#TEST en CLAIR
import random
import string
import io
import sys
def str_nombreJEJE(message):
    chaine=""
    for i in message:
        chaine=chaine+bin(ord(i))[2:].rjust(7,"0")
    return int(chaine,2)
def getPasswordJEJE(length):

    str = string.ascii_letters
    return ''.join(random.choice(str) for i in  range(length))

erreur=False


for i in range(10000):
    m=random.randint(4,15)
    a=getPasswordJEJE(m)
    if type(str_nombre(a))!=int:
        print("Le type de sorti n'est pas correct")
        erreur=True
        break
    elif len(bin(str_nombre(a))[2:])%7!=0 and len(bin(str_nombre(a))[2:])%7!=6:
        print("La taille de la chaine",a,"n'est pas correct.")
        erreur=True
        break
    elif str_nombreJEJE(a)!=str_nombre(a):
                print("Il y a une erreur avec le mot",a)
                erreur=True
                break
if erreur==False:
    print("Bravo votre code me semble operationnel.")
#TEST DOCUMENTAITON

def testDoc(f):
    stdout_ = sys.stdout
    sys.stdout = io.StringIO()
    try:
        help(f)
        s1 = sys.stdout.getvalue()
        sys.stdout = stdout_
        s1.lower()
        if "out" not in s1:
            print("Votre documentation est incomplete.\n")
    except:
        sys.stdout = stdout_
        help(f)

testDoc(str_nombre)
# Out:
# Le type de sorti n'est pas correct
# Votre documentation est incomplete.

# %%
#Votre code ici
def chiffreMasque(message):

# %%
#TESTER VOTRE CODE ICI
exec(bytes('吣卅⁔湥䌠䅌剉椊灭牯⁴慲摮浯椊灭牯⁴瑳楲杮椊灭牯⁴潩椊灭牯⁴祳ੳ敤⁦瑳彲潮扭敲䕊䕊洨獥慳敧㨩 †挠慨湩㵥∢ †映牯椠椠⁮敭獳条㩥 †††挠慨湩㵥档楡敮戫湩漨摲椨⤩㉛崺爮番瑳㜨∬∰਩††敲畴湲椠瑮挨慨湩ⱥ⤲搊晥朠瑥慐獳潷摲䕊䕊氨湥瑧⥨਺††瑳⁲‽瑳楲杮愮捳楩江瑥整獲 †爠瑥牵⁮✧樮楯⡮慲摮浯挮潨捩⡥瑳⥲映牯椠椠⁮爠湡敧氨湥瑧⥨਩‣⁁潣浭湥整ੲ敤⁦敤档晩牦䵥獡畱䩥䩅⡅档晩牦ⱥ汣晥㨩 †∠∢ †䤠㩮椠瑮椬瑮 †传瑵›瑳ੲ††∢ਢ††汣楡敲∽ਢ††㵡档晩牦幥汣晥 †愠戽湩愨嬩㨲੝††晩氠湥戨湩猨牴湟浯牢⡥⥡⤩㜥㴽㨶 †††戠椽瑮愨㩛崶㈬਩††††㵡孡㨶੝††††汣楡敲㴫档⡲⥢ †眠楨敬愠㴡∢਺††††㵢湩⡴孡㜺ⱝ⤲ †††愠愽㝛崺 †††挠慬物⭥挽牨戨਩††敲畴湲挠慬物੥敤⁦档晩牦䵥獡畱䩥䩅⡅敭獳条⥥਺††㵬敬⡮敭獳条⥥ †挠敬㵦瑳彲潮扭敲䕊䕊木瑥慐獳潷摲䕊䕊氨⤩ †挠慬物十䥃㵉瑳彲潮扭敲䕊䕊洨獥慳敧਩††敲畴湲挠敬幦汣楡䅲䍓䥉挬敬੦牥敲牵䘽污敳昊牯椠椠⁮慲杮⡥〱〰⤰਺††㵭慲摮浯爮湡楤瑮㐨ㄬ⤵ †挠慬物朽瑥慐獳潷摲洨਩††㵡档晩牦䵥獡畱⡥汣楡⥲ †椠⁦祴数愨℩琽灵敬਺††††牰湩⡴䰢⁥祴数搠⁥潳瑲⁩❮獥⁴慰⁳潣牲捥≴਩††††牥敲牵吽畲੥††††牢慥੫††汥晩琠灹⡥孡崰℩椽瑮਺††††牰湩⡴䰢⁥祴数搠⁥潳瑲⁩❮獥⁴慰⁳潣牲捥≴਩††††牥敲牵吽畲੥††††牢慥੫††汥晩琠灹⡥孡崱℩椽瑮਺††††牰湩⡴䰢⁥祴数搠⁥潳瑲⁩❮獥⁴慰⁳潣牲捥≴਩††††牥敲牵吽畲੥††††牢慥੫††晩搠捥楨晦敲慍煳敵䕊䕊愨せⱝ孡崱℩挽慬物਺††††††††牰湩⡴䤢⁬⁹⁡湵⁥牥敲牵愠敶⁣敬洠瑯Ⱒ汣楡⥲ †††††††攠牲略㵲牔敵 †††††††戠敲歡椊⁦牥敲牵㴽慆獬㩥 †瀠楲瑮∨牂癡⁯潶牴⁥潣敤洠⁥敳扭敬漠数慲楴湯敮⹬⤢⌊䕔呓䐠䍏䵕久䅔呉乏搊晥琠獥䑴捯昨㨩 †猠摴畯彴㴠猠獹献摴畯ੴ††祳⹳瑳潤瑵㴠椠⹯瑓楲杮佉⤨ †琠祲਺††††敨灬昨਩††††ㅳ㴠猠獹献摴畯⹴敧癴污敵⤨ †††猠獹献摴畯⁴‽瑳潤瑵੟††††ㅳ氮睯牥⤨ †††椠⁦漢瑵•潮⁴湩猠㨱 †††††瀠楲瑮∨潖牴⁥潤畣敭瑮瑡潩⁮獥⁴湩潣灭敬整尮≮਩††硥散瑰਺††††祳⹳瑳潤瑵㴠猠摴畯彴 †††栠汥⡰⥦琊獥䑴捯挨楨晦敲慍煳敵','u16')[2:])

# %%
#TEST en CLAIR
import random
import string
import io
import sys
def str_nombreJEJE(message):
    chaine=""
    for i in message:
        chaine=chaine+bin(ord(i))[2:].rjust(7,"0")
    return int(chaine,2)
def getPasswordJEJE(length):
    str = string.ascii_letters
    return ''.join(random.choice(str) for i in  range(length))

# A commenter
def dechiffreMasqueJEJE(chiffre,clef):
    """
    In: int,int
    Out: str
    """
    claire=""
    a=chiffre^clef
    a=bin(a)[2:]
    
    if len(bin(str_nombre(a)))%7==6:
        b=int(a[:6],2)
        a=a[6:]
        claire+=chr(b)        
    while a!="":
        b=int(a[:7],2)
        a=a[7:]
        claire+=chr(b)
    return claire
def chiffreMasqueJEJE(message):
    l=len(message)
    clef=str_nombreJEJE(getPasswordJEJE(l))
    
    clairASCII=str_nombreJEJE(message)
    return clef^clairASCII,clef
erreur=False


for i in range(10000):
    m=random.randint(4,15)
    clair=getPassword(m)
    a=chiffreMasque(clair)
    if type(a)!=tuple:
        print("Le type de sorti n'est pas correct")
        erreur=True    
        break
    elif type(a[0])!=int:
        print("Le type de sorti n'est pas correct")
        erreur=True    
        break
    elif type(a[1])!=int:
        print("Le type de sorti n'est pas correct")
        erreur=True    
        break
         
    if dechiffreMasqueJEJE(a[0],a[1])!=clair:
                print("Il y a une erreur avec le mot",clair)
                erreur=True
                break
if erreur==False:
    print("Bravo votre code me semble operationnel.")
#TEST DOCUMENTAITON

def testDoc(f):
    stdout_ = sys.stdout
    sys.stdout = io.StringIO()
    try:
        help(f)
        s1 = sys.stdout.getvalue()
        sys.stdout = stdout_
        s1.lower()
        if "out" not in s1:
            print("Votre documentation est incomplete.\n")
    except:
        sys.stdout = stdout_
        help(f)

testDoc(chiffreMasque)

# %%
# A commenter
def dechiffreMasque(chiffre,clef):
    """
    In: int,int
    Out: str
    """
    claire=""
    a=chiffre^clef
    a=bin(a)[2:]     
    while a!="":
        b=int(a[:7],2)
        a=a[7:]
        claire+=chr(b)
    return claire

dechiffreMasque(327103,1528950)

# %% [markdown]
# Le masque jetable est **le meilleur chiffrement possible**. Le probleme du masque jetable est qu'il faut avoir une clef de la taille du message. Pour un chiffrement plus souple on a

# %% [markdown]
# # Le chifrement de Vigenère
#
# On se donne une clé de taille $l$. On decoupe le message clair en morceaux de la taille de la clef et on chiffre chaque morceau. Si par exemple on utilise la clef "MUSIQUE", on chiffre la phrase
#
# J'ADORE ECOUTER LA RADIO TOUTE LA JOURNEE en faisant un XOR avec MUSIQUEMUSIQUEMUSIQUEMUSIQUEMUSIQUEMUSIQU
#
# | |J|'|A|D|O|R|E| |E|C|O|U|T|E|R| |L|A| |R|A|D|I|O| |T|O|U|T|E| |L|A| |J|O|U|R|N|E|E|
# |-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|
# XOR|M|U|S|I|Q|U|E|M|U|S|I|Q|U|E|M|U|S|I|Q|U|E|M|U|S|I|Q|U|E|M|U|S|I|Q|U|E|M|U|S|I|Q|U|
#
# ### Exercice 3
# Regarder ce code qui utilise le principe du chiffrement de Vigenère et commenter chaque ligne.

# %%
def chiffreVigenere(clair,clef):
    """
    In: str,str
    Out: str sous forme binaire
    """
    j=0
    chiffre=""
    
    while j<len(A):
        i=0
        while j<len(A) and i<len(clef):
            a=ord(A[j])^ord(clef[i])
            a=bin(a)
            a=a[2:]
            a=a.rjust(7,"0")
            chiffre=chiffre+a
            i+=1
            j+=1
    return chiffre

A="J'ADORE ECOUTER LA MUSIQUE TOUTE LA JOURNEE"
K="MUSIQUE"
monChiffre=chiffreVigenere(A,K)
print("Sous la forme d'une suite de bits\n",monChiffre  )
print("Sous la forme d'un entier\n",int(monChiffre,2)  )
print("Sous la forme d'un entier écrit en hexadecimale\n",hex(int(monChiffre,2)  ))

# %% [markdown]
# Evidemment si voulez le représenter sous forme d'une chaine de caractere "lisible" c'est plus délicat car si on essaye de transformer grace à l'UTF16 on obtient cela :

# %%
monchiffre=monChiffre
lisible=""
while monchiffre!="":
    i=0
    while monchiffre!="" and i<len(K):
        a=monchiffre[:16]
        monchiffre=monchiffre[16:]
        a=int(a,2)
        lisible+= chr(a)
        i+=1
lisible

# %% [markdown]
# On peut s'amuser à se débrouiller pour faire un chiffré plus lisible mais cela ne servirait pas à grand chose. Voici la méthode de déchiffrement.
#
# ### Exercice 4 (déchiffrement)
# Regarder ce code pour déchiffrer un chiffrer de Vigenère et commenter chaque ligne. Pourquoi coupe-t-on en bloc de 7 ?

# %%
def dechiffrementVigenere(monchiffre,K):
    claire=""
    while monchiffre!="":
        i=0
        while monchiffre!="" and i<len(K):
            a=monchiffre[:7]
            monchiffre=monchiffre[7:]
            a=int(a,2)
            b=a^ord(K[i])
            claire+=chr(b)
            i+=1
    return claire
dechiffrementVigenere(monChiffre,"MUSIQUE")

# %% [markdown]
# # Les chiffrements symetriques modernes
# ## Le Data Encryption Standard (DES)
#
# Le Data Encryption Standard (DES, prononcer /dɛs/) est un algorithme de chiffrement symétrique (chiffrement par bloc) utilisant des clés de 56 bits. Son emploi n'est plus recommandé aujourd'hui, du fait de sa lenteur à l'exécution et de son espace de clés trop petit permettant une attaque systématique en un temps raisonnable. Quand il est encore utilisé c'est généralement en Triple DES, ce qui ne fait rien pour améliorer ses performances. DES a notamment été utilisé dans le système de mots de passe UNIX.
#
# Le premier standard DES est publié par FIPS le 15 janvier 1977 sous le nom FIPS PUB 46. La dernière version avant l'obsolescence date du 25 octobre 1991.
#
# ## Advanced Encryption Standard (AES)
# Advanced Encryption Standard ou AES (litt. « norme de chiffrement avancé »), aussi connu sous le nom de Rijndael, est un algorithme de chiffrement symétrique. Il remporta en octobre 2000 le concours AES, lancé en 1997 par le NIST et devint le nouveau standard de chiffrement pour les organisations du gouvernement des États-Unis. Il a été approuvé par la NSA (National Security Agency) dans sa suite B1 des algorithmes cryptographiques. Il est actuellement le plus utilisé et le plus sûr.

# %%
# Ce code ne fonctionne pas sur Capytale

from Crypto.Cipher import AES
obj = AES.new('une grosse clef', AES.MODE_CBC, "une graine pour de l'aleatoire")
message = "The answer is no"
ciphertext = obj.encrypt(message)
print(ciphertext)
'\xd6\x83\x8dd!VT\x92\xaa`A\x05\xe0\x9b\x8b\xf1'
obj2 = AES.new('une grosse clef', AES.MODE_CBC, "une graine pour de l'aleatoire")
print(obj2.decrypt(ciphertext))
'The answer is no'
